# %%
# !pip install --upgrade pip
# !pip install tensorflow wandb numpy pandas tqdm
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.9 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.1.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.72.0rc1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (7.0.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.25.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.1.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import wandb
wandb.login(key='613aac3388325cb6206db61e3c1a38a707589743')
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: da24s006 (da24s006-indian-institue-of-technology-madras-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Data Preparation:
# - downloading and extracting dikshina hindi lexicon: already downloaded and uploaded the relavant part of the data in the kaggle environment.
# - building character vocabularies and dataloader.

# %%
# data_utils.py
import pandas as pd
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset

def build_vocab(pairs, specials=['<pad>','<sos>','<eos>']):
    chars = set(''.join(pairs))
    idx = {tok:i for i,tok in enumerate(specials)}
    for c in sorted(chars):
        idx[c] = len(idx)
    return idx

class TransliterationDataset(Dataset):
    def __init__(self, path, src_vocab, tgt_vocab, max_len=32):
        df = pd.read_csv(path, sep='\t', names=['devanagari','roman','dont_care'])
        df = df.dropna()
        self.pairs = df[['roman','devanagari']].values.tolist()
        self.src_vocab, self.tgt_vocab = src_vocab, tgt_vocab
        self.max_len = max_len

    def __len__(self): return len(self.pairs)

    def __getitem__(self, i):
        src, tgt = self.pairs[i]
        # src: [c1,c2,...] -> [..., <eos>]
        src_ids = [self.src_vocab[c] for c in src][:self.max_len] + [self.src_vocab['<eos>']]
        # tgt: [<sos>, c1,c2,..., <eos>]
        tgt_ids = [self.tgt_vocab['<sos>']] + \
                  [self.tgt_vocab[c] for c in tgt][:self.max_len] + \
                  [self.tgt_vocab['<eos>']]
        return torch.tensor(src_ids, dtype=torch.long), torch.tensor(tgt_ids, dtype=torch.long)

def collate_fn(batch):
    srcs, tgts = zip(*batch)
    srcs_p = pad_sequence(srcs, batch_first=True, padding_value=src_vocab['<pad>'])
    tgts_p = pad_sequence(tgts, batch_first=True, padding_value=tgt_vocab['<pad>'])
    return srcs_p, tgts_p

# Build vocabs once
df = pd.read_csv('/kaggle/input/transliteration-9123/hi.translit.sampled.train.tsv', sep='\t', names=['devanagari','roman','dont_care'])
df = df.dropna()
src_vocab = build_vocab(df['roman'])
tgt_vocab = build_vocab(df['devanagari'])

# %% [markdown]
# # Model Definition
# - Encoder and Decoder class

# %%
# model.py
import torch, torch.nn as nn, torch.nn.functional as F

class Encoder(nn.Module):
    
    def __init__(self, inp_dim, emb_dim, hid_dim, n_layers, cell, dropout):
        super().__init__()
        self.emb = nn.Embedding(inp_dim, emb_dim)
        RNN = {'RNN': nn.RNN, 'LSTM': nn.LSTM, 'GRU': nn.GRU}[cell]
        self.rnn = RNN(emb_dim, hid_dim, n_layers,
                       dropout=dropout if n_layers>1 else 0,
                       batch_first=True)
        self.drop = nn.Dropout(dropout)
        
    def forward(self, x):
        # x: [B, S]
        e = self.drop(self.emb(x))
        out, hidden = self.rnn(e)
        return out, hidden

class Attention(nn.Module):
    
    def __init__(self, hid_dim):
        super().__init__()
        self.attn = nn.Linear(hid_dim*2, hid_dim)
        self.v    = nn.Linear(hid_dim, 1, bias=False)
        
    def forward(self, hidden, enc_out):
        # hidden: [B, H], enc_out: [B, S, H]
        B, S, H = enc_out.size()
        h = hidden.unsqueeze(1).repeat(1,S,1)               # [B,S,H]
        energy = torch.tanh(self.attn(torch.cat([h,enc_out],dim=2)))  # [B,S,H]
        scores = self.v(energy).squeeze(2)                  # [B,S]
        return F.softmax(scores, dim=1)

class Decoder(nn.Module):
    
    def __init__(self, out_dim, emb_dim, hid_dim, n_layers, cell, dropout, use_attn=False):
        super().__init__()
        self.emb = nn.Embedding(out_dim, emb_dim)
        RNN = {'RNN': nn.RNN, 'LSTM': nn.LSTM, 'GRU': nn.GRU}[cell]
        self.rnn = RNN(emb_dim + (hid_dim if use_attn else 0),
                       hid_dim, n_layers,
                       dropout=dropout if n_layers>1 else 0,
                       batch_first=True)
        self.fc  = nn.Linear(hid_dim, out_dim)
        self.drop = nn.Dropout(dropout)
        self.use_attn = use_attn
        if use_attn: self.attn = Attention(hid_dim)

    def forward(self, tgt_tok, hidden, enc_out=None):
        # tgt_tok: [B], hidden: (h_n, c_n)? or h_n
        B = tgt_tok.size(0)
        t = tgt_tok.unsqueeze(1)            # [B,1]
        emb = self.drop(self.emb(t))        # [B,1,E]
        
        if self.use_attn:
            h = hidden[-1] if not isinstance(hidden, tuple) else hidden[0][-1]
            attn_w = self.attn(h, enc_out)  # [B, S]
            ctx    = torch.bmm(attn_w.unsqueeze(1), enc_out)  # [B,1,H]
            rnn_in = torch.cat([emb, ctx], dim=2)
        else:
            rnn_in = emb
        out, hidden = self.rnn(rnn_in, hidden)
        pred = self.fc(out.squeeze(1))      # [B, out_dim]
        
        return pred, hidden, (attn_w if self.use_attn else None)

class Seq2Seq(nn.Module):
    def __init__(self, enc, dec, pad_idx, device):
        super().__init__()
        self.enc, self.dec = enc, dec
        self.pad_idx = pad_idx
        self.device  = device

    # def _init_decoder_hidden(self, enc_hidden):
    #     # Handles both GRU (Tensor) and LSTM (tuple) encoder hidden states
    #     if isinstance(enc_hidden, tuple):  # LSTM: (h_n, c_n)
    #         h, c = enc_hidden
    #         dec_layers = self.dec.rnn.num_layers
    #         B, H = h.size(1), h.size(2)
    #         # Prepare zero-padded states
    #         h0 = torch.zeros(dec_layers, B, H, device=self.device)
    #         c0 = torch.zeros(dec_layers, B, H, device=self.device)
    #         # Copy encoder layers into decoder state
    #         h0[:h.size(0)] = h
    #         c0[:c.size(0)] = c
    #         return (h0, c0)
    #     else:  # GRU or RNN
    #         h = enc_hidden
    #         dec_layers = self.dec.rnn.num_layers
    #         B, H = h.size(1), h.size(2)
    #         h0 = torch.zeros(dec_layers, B, H, device=self.device)
    #         h0[:h.size(0)] = h
    #         return h0

    def _init_decoder_hidden(self, enc_hidden):
        """
        Align encoder hidden states to decoder.num_layers by:
        - copying the last min(enc_layers, dec_layers) layers when
          decoder has fewer layers,
        - zero‐padding above when decoder has more layers.
        Supports both GRU/RNN (Tensor) and LSTM (tuple).
        """
        dec_layers = self.dec.rnn.num_layers
    
        if isinstance(enc_hidden, tuple):  # LSTM: (h, c)
            h, c = enc_hidden
            enc_layers, B, H = h.size()
            # Prepare zero states
            h0 = torch.zeros(dec_layers,  B, H, device=self.device)
            c0 = torch.zeros(dec_layers,  B, H, device=self.device)
            # Number of layers to copy
            n = min(enc_layers, dec_layers)
            # Copy last n layers from encoder into bottom of decoder state
            h0[-n:] = h[-n:]
            c0[-n:] = c[-n:]
            return (h0, c0)

        else:  # GRU or vanilla RNN
            h = enc_hidden
            enc_layers, B, H = h.size()
            h0 = torch.zeros(dec_layers, B, H, device=self.device)
            n = min(enc_layers, dec_layers)
            h0[-n:] = h[-n:]
            return h0


    def forward(self, src, tgt, teacher_forcing=0.5):
        B, T = tgt.size()
        out_dim = self.dec.fc.out_features
        outputs = torch.zeros(B, T, out_dim, device=self.device)

        enc_out, enc_hidden = self.enc(src)
        # Initialize decoder hidden state to match dec_layers
        dec_hidden = self._init_decoder_hidden(enc_hidden)

        inp = tgt[:,0]  # <sos>
        for t in range(1, T):
            pred, dec_hidden, _ = self.dec(
                inp, dec_hidden,
                enc_out if self.dec.use_attn else None
            )
            outputs[:,t] = pred
            top1 = pred.argmax(1)
            inp = tgt[:,t] if torch.rand(1).item() < teacher_forcing else top1

        return outputs

# %% [markdown]
# # Beam Search Decoding

# %%
# beam_search.py
import torch, torch.nn.functional as F
from queue import PriorityQueue
from math import log

class BeamNode:
    def __init__(self, hidden, prev, tok, logp, length):
        self.hidden, self.prev, self.tok = hidden, prev, tok
        self.logp, self.len = logp, length
    def score(self): return self.logp / float(self.len)

def beam_decode(model, src, src_vocab, tgt_vocab, beam_k=3, max_len=32, device='cpu'):
    model.eval()
    with torch.no_grad():
        enc_out, hidden = model.enc(src)
        # init beam
        init_tok = torch.tensor([tgt_vocab['<sos>']], device=device)
        node = BeamNode(hidden, None, init_tok, 0.0, 1)
        pq = PriorityQueue(); pq.put((-node.score(), node))
        end_beams = []
        while not pq.empty():
            _, n = pq.get()
            if n.tok.item()==tgt_vocab['<eos>'] and n.prev is not None:
                end_beams.append((n.score(), n))
                if len(end_beams)>=beam_k: break
            inp = n.tok
            pred, hid, _ = model.dec(inp, n.hidden, enc_out if model.dec.use_attn else None)
            logps = F.log_softmax(pred, dim=1)
            topv, topi = logps.topk(beam_k)
            for i in range(beam_k):
                tok_i = topi[0][i].unsqueeze(0)
                score = n.logp + topv[0][i].item()
                new_node = BeamNode(hid, n, tok_i, score, n.len+1)
                pq.put((-new_node.score(), new_node))
        # backtrack best
        best = sorted(end_beams, key=lambda x: x[0], reverse=True)[0][1]
        seq = []
        while best.prev is not None:
            seq.append(best.tok.item()); best = best.prev
        return seq[::-1]

# %% [markdown]
# # 4. Training, Evaluation & W&B Sweep

# %%
# train.py
import wandb, torch, torch.optim as optim, torch.nn as nn
# from data_utils import TransliterationDataset, collate_fn, src_vocab, tgt_vocab
# from model import Encoder, Decoder, Seq2Seq
# from beam_search import beam_decode
from torch.utils.data import DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pad_idx = tgt_vocab['<pad>']

sweep_config = {
  'method': 'bayes',
  'metric': {'name':'val_loss','goal':'minimize'},
  'parameters':{
    'emb_dim':   {'values':[16,32,64,256]},
    'hid_dim':   {'values':[16,32,64,256]},
    'enc_layers':{'values':[1,2,3]},
    'dec_layers':{'values':[1,2,3]},
    'cell_type': {'values':['RNN','GRU','LSTM']},
    'dropout':   {'values':[0.2,0.3]},
    'beam_size': {'values':[1,3,5]},
    'lr':        {'value':1e-3},
    'batch_size':{'value':128},
      'use_attn': {'values':[True, False]}
  }
}

# %%
# def train_epoch(model, loader, opt, crit):
#     model.train(); total=0
#     for src, tgt in loader:
#         src, tgt = src.to(device), tgt.to(device)
#         opt.zero_grad()
#         out = model(src, tgt,teacher_forcing=0.5)
#         loss = crit(out[:,1:].reshape(-1,out.size(-1)), tgt[:,1:].reshape(-1))
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(),1)
#         opt.step(); total += loss.item()
#     return total/len(loader)

# def eval_epoch(model, loader, crit, beam_k):
#     model.eval(); total=0
#     with torch.no_grad():
#         for src,tgt in loader:
#             src,tgt = src.to(device), tgt.to(device)
#             # teacher_forced loss
#             out = model(src,tgt,teacher_forcing=0.0)
#             total += crit(out[:,1:].reshape(-1,out.size(-1)), tgt[:,1:].reshape(-1)).item()
#     return total/len(loader)

def calculate_accuracy(output, target, pad_idx):
    # output: [B, T, V], target: [B, T]
    with torch.no_grad():
        pred_tokens = output.argmax(dim=2)           # [B, T]
        mask        = target != pad_idx              # ignore pads
        correct     = (pred_tokens == target) & mask
        return correct.sum().float() / mask.sum().float()

def train_epoch(model, loader, opt, crit, pad_idx):
    model.train()
    total_loss = 0
    total_acc  = 0
    for src, tgt in loader:
        src, tgt = src.to(device), tgt.to(device)
        opt.zero_grad()
        out  = model(src, tgt, teacher_forcing=0.5)
        loss = crit(out[:,1:].reshape(-1,out.size(-1)), tgt[:,1:].reshape(-1))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
        opt.step()

        total_loss += loss.item()
        total_acc  += calculate_accuracy(out[:,1:], tgt[:,1:], pad_idx)
    return total_loss/len(loader), total_acc/len(loader)

def eval_epoch(model, loader, crit, beam_k, pad_idx):
    model.eval()
    total_loss = 0
    total_acc  = 0
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            out  = model(src, tgt, teacher_forcing=0.0)
            loss = crit(out[:,1:].reshape(-1,out.size(-1)), tgt[:,1:].reshape(-1))

            total_loss += loss.item()
            total_acc  += calculate_accuracy(out[:,1:], tgt[:,1:], pad_idx)
    return total_loss/len(loader), total_acc/len(loader)

# %%
def sweep_run():
    wandb.init()
    cfg = wandb.config
    
    # data
    ds = TransliterationDataset('/kaggle/input/transliteration-9123/hi.translit.sampled.train.tsv', src_vocab, tgt_vocab)
    dv = TransliterationDataset('/kaggle/input/transliteration-9123/hi.translit.sampled.dev.tsv', src_vocab, tgt_vocab)
    dl = DataLoader(ds, batch_size=cfg.batch_size, collate_fn=collate_fn, shuffle=True)
    val_dl = DataLoader(dv, batch_size=cfg.batch_size, collate_fn=collate_fn)
    
    # model
    enc = Encoder(len(src_vocab), cfg.emb_dim, cfg.hid_dim, cfg.enc_layers, cfg.cell_type, cfg.dropout)
    dec = Decoder(len(tgt_vocab), cfg.emb_dim, cfg.hid_dim, cfg.dec_layers, cfg.cell_type, cfg.dropout, cfg.use_attn)
    model = Seq2Seq(enc,dec,pad_idx,device).to(device)
    opt   = optim.Adam(model.parameters(), lr=cfg.lr)
    crit  = nn.CrossEntropyLoss(ignore_index=pad_idx)

    for epoch in range(1, 11):
        tr_loss, tr_acc = train_epoch(model, dl, opt, crit, pad_idx)
        vl_loss, vl_acc = eval_epoch(model, val_dl, crit, cfg.beam_size, pad_idx)
        wandb.log({
            'epoch':       epoch,
            'train_loss':  tr_loss,
            'train_acc':   tr_acc,
            'val_loss':    vl_loss,
            'val_acc':     vl_acc
        })
            
    # save best
    torch.save(model.state_dict(),'model_use_attn.pt')
    wandb.save('model.pt')

if __name__=='__main__':
    sweep_id = wandb.sweep(sweep_config, project='dakshina-translit')
    wandb.agent(sweep_id, function=sweep_run, count=200)
# Out:
# Create sweep with ID: lq4q39fn
# Sweep URL: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: Agent Starting Run: nt7vza5y with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 3
# wandb: 	cell_type: RNN
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	enc_layers: 3
# wandb: 	hid_dim: 64
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_211243-nt7vza5y
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run astral-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/nt7vza5y
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▅▆▇█████
# wandb: train_loss █▅▄▃▂▁▁▁▁▁
# wandb:    val_acc ▁▄▄▆▇█▇▆▇▅
# wandb:   val_loss █▆▅▃▃▁▂▃▂▃
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.25709
# wandb: train_loss 2.79815
# wandb:    val_acc 0.20269
# wandb:   val_loss 3.05542
# wandb:
# wandb: 🚀 View run astral-sweep-1 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/nt7vza5y
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_211243-nt7vza5y/logs
# wandb: Agent Starting Run: 8jchken5 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 3
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 32
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_211420-8jchken5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run drawn-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/8jchken5
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▂▃▄▅▅▆▇▇█
# wandb: train_loss █▆▆▅▄▃▂▂▁▁
# wandb:    val_acc ▁▂▂▃▄▅▆▆▇█
# wandb:   val_loss █▇▇▆▅▄▃▂▂▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.36814
# wandb: train_loss 2.24894
# wandb:    val_acc 0.36436
# wandb:   val_loss 2.28553
# wandb:
# wandb: 🚀 View run drawn-sweep-2 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/8jchken5
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_211420-8jchken5/logs
# wandb: Agent Starting Run: gt8hzr0j with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 3
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 32
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 16
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_211702-gt8hzr0j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run rural-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/gt8hzr0j
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▅▅▆▇▇▇██
# wandb: train_loss █▅▄▄▃▃▂▂▁▁
# wandb:    val_acc ▂▂▁▂▅▅▆█▇█
# wandb:   val_loss █▇▇▆▅▄▃▂▂▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.2979
# wandb: train_loss 2.60824
# wandb:    val_acc 0.25624
# wandb:   val_loss 2.80173
# wandb:
# wandb: 🚀 View run rural-sweep-3 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/gt8hzr0j
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_211702-gt8hzr0j/logs
# wandb: Agent Starting Run: xcyhiecb with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 3
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 16
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_211829-xcyhiecb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run legendary-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/xcyhiecb
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▄▅▆▆▇▇██
# wandb: train_loss █▆▅▄▃▃▂▂▁▁
# wandb:    val_acc ▁▁▃▅▅▆▇███
# wandb:   val_loss █▇▆▅▄▃▃▂▂▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.32145
# wandb: train_loss 2.43142
# wandb:    val_acc 0.28771
# wandb:   val_loss 2.59553
# wandb:
# wandb: 🚀 View run legendary-sweep-4 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/xcyhiecb
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_211829-xcyhiecb/logs
# wandb: Agent Starting Run: f4lfhowf with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: RNN
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 16
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_212016-f4lfhowf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run laced-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/f4lfhowf
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▆▆▆▆▇▇███
# wandb: train_loss █▃▂▂▂▂▂▁▁▁
# wandb:    val_acc ██████▅█▁▄
# wandb:   val_loss ▃▂▂▁▁▁▄▁█▅
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.22278
# wandb: train_loss 2.97223
# wandb:    val_acc 0.1652
# wandb:   val_loss 3.24807
# wandb:
# wandb: 🚀 View run laced-sweep-5 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/f4lfhowf
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_212016-f4lfhowf/logs
# wandb: Agent Starting Run: lmdkhkc7 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 64
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_212152-lmdkhkc7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lucky-sweep-6
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/lmdkhkc7
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▂▃▄▅▆▇▇██
# wandb: train_loss █▇▆▅▄▃▂▂▁▁
# wandb:    val_acc ▁▂▃▄▅▆▇▇██
# wandb:   val_loss █▇▆▄▃▃▂▂▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.5601
# wandb: train_loss 1.45679
# wandb:    val_acc 0.52733
# wandb:   val_loss 1.58228
# wandb:
# wandb: 🚀 View run lucky-sweep-6 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/lmdkhkc7
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_212152-lmdkhkc7/logs
# wandb: Agent Starting Run: 6uvq7sat with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_212354-6uvq7sat
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run logical-sweep-7
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/6uvq7sat
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▅▃▂▂▁▁▁▁▁
# wandb:    val_acc ▁▅▇▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84477
# wandb: train_loss 0.51164
# wandb:    val_acc 0.7292
# wandb:   val_loss 0.99809
# wandb:
# wandb: 🚀 View run logical-sweep-7 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/6uvq7sat
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_212354-6uvq7sat/logs
# wandb: Agent Starting Run: p9zwhea9 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_212651-p9zwhea9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run misty-sweep-8
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/p9zwhea9
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▅▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▃▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.86347
# wandb: train_loss 0.45921
# wandb:    val_acc 0.71684
# wandb:   val_loss 1.08192
# wandb:
# wandb: 🚀 View run misty-sweep-8 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/p9zwhea9
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_212651-p9zwhea9/logs
# wandb: Agent Starting Run: us6pblzr with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_212848-us6pblzr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run classic-sweep-9
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/us6pblzr
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▅▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84758
# wandb: train_loss 0.5042
# wandb:    val_acc 0.71496
# wandb:   val_loss 1.04171
# wandb:
# wandb: 🚀 View run classic-sweep-9 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/us6pblzr
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_212848-us6pblzr/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: k9uj2xzh with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_213155-k9uj2xzh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run woven-sweep-10
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/k9uj2xzh
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▄▃▂▂▁▁▁▁▁
# wandb:    val_acc ▁▅▇▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.86788
# wandb: train_loss 0.44377
# wandb:    val_acc 0.72979
# wandb:   val_loss 1.02392
# wandb:
# wandb: 🚀 View run woven-sweep-10 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/k9uj2xzh
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_213155-k9uj2xzh/logs
# wandb: Agent Starting Run: dsoey4b5 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_213454-dsoey4b5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run hopeful-sweep-11
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/dsoey4b5
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▅▇▇▇█████
# wandb: train_loss █▃▂▂▂▁▁▁▁▁
# wandb:    val_acc ▁▆▇▇██████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.86721
# wandb: train_loss 0.44183
# wandb:    val_acc 0.73468
# wandb:   val_loss 0.97101
# wandb:
# wandb: 🚀 View run hopeful-sweep-11 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/dsoey4b5
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_213454-dsoey4b5/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 4vaaeo51 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_213740-4vaaeo51
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run colorful-sweep-12
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/4vaaeo51
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇▇████
# wandb:   val_loss █▄▃▂▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.83554
# wandb: train_loss 0.55206
# wandb:    val_acc 0.69582
# wandb:   val_loss 1.10161
# wandb:
# wandb: 🚀 View run colorful-sweep-12 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/4vaaeo51
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_213740-4vaaeo51/logs
# wandb: Agent Starting Run: 2ib1erf6 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_213918-2ib1erf6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run twilight-sweep-13
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/2ib1erf6
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇▇▇███
# wandb:   val_loss █▄▃▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84038
# wandb: train_loss 0.53052
# wandb:    val_acc 0.69503
# wandb:   val_loss 1.10336
# wandb:
# wandb: 🚀 View run twilight-sweep-13 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/2ib1erf6
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_213918-2ib1erf6/logs
# wandb: Agent Starting Run: hwcf57yv with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_214129-hwcf57yv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run genial-sweep-14
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/hwcf57yv
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▅▆▇▇▇████
# wandb: train_loss █▄▂▂▂▁▁▁▁▁
# wandb:    val_acc ▁▆▇▇██████
# wandb:   val_loss █▃▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.85403
# wandb: train_loss 0.48303
# wandb:    val_acc 0.73567
# wandb:   val_loss 0.96793
# wandb:
# wandb: 🚀 View run genial-sweep-14 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/hwcf57yv
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_214129-hwcf57yv/logs
# wandb: Agent Starting Run: aaj1x7p0 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_214357-aaj1x7p0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crisp-sweep-15
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/aaj1x7p0
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▅▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇▇████
# wandb:   val_loss █▄▃▂▁▁▁▂▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.85243
# wandb: train_loss 0.49748
# wandb:    val_acc 0.70285
# wandb:   val_loss 1.06799
# wandb:
# wandb: 🚀 View run crisp-sweep-15 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/aaj1x7p0
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_214357-aaj1x7p0/logs
# wandb: Agent Starting Run: 817lnzi2 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_214553-817lnzi2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run toasty-sweep-16
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/817lnzi2
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▅▆▇▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84699
# wandb: train_loss 0.5116
# wandb:    val_acc 0.70909
# wandb:   val_loss 1.04802
# wandb:
# wandb: 🚀 View run toasty-sweep-16 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/817lnzi2
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_214553-817lnzi2/logs
# wandb: Agent Starting Run: lxguzga0 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 64
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_214735-lxguzga0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run colorful-sweep-17
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/lxguzga0
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▅▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.83283
# wandb: train_loss 0.55395
# wandb:    val_acc 0.70195
# wandb:   val_loss 1.06102
# wandb:
# wandb: 🚀 View run colorful-sweep-17 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/lxguzga0
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_214735-lxguzga0/logs
# wandb: Agent Starting Run: oh2b1zzl with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 3
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_214912-oh2b1zzl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run neat-sweep-18
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/oh2b1zzl
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▃▂▂▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84446
# wandb: train_loss 0.52299
# wandb:    val_acc 0.69707
# wandb:   val_loss 1.10629
# wandb:
# wandb: 🚀 View run neat-sweep-18 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/oh2b1zzl
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_214912-oh2b1zzl/logs
# wandb: Agent Starting Run: q7yx4zox with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 3
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_215108-q7yx4zox
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vital-sweep-19
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/q7yx4zox
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇▇████
# wandb:   val_loss █▄▃▂▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.82324
# wandb: train_loss 0.59089
# wandb:    val_acc 0.69476
# wandb:   val_loss 1.08605
# wandb:
# wandb: 🚀 View run vital-sweep-19 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/q7yx4zox
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_215108-q7yx4zox/logs
# wandb: Agent Starting Run: mc1ul77a with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_215244-mc1ul77a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run swept-sweep-20
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/mc1ul77a
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇▇████
# wandb:   val_loss █▃▂▂▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.83733
# wandb: train_loss 0.54217
# wandb:    val_acc 0.69216
# wandb:   val_loss 1.09165
# wandb:
# wandb: 🚀 View run swept-sweep-20 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/mc1ul77a
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_215244-mc1ul77a/logs
# wandb: Agent Starting Run: xn13uuik with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 64
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_215442-xn13uuik
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lilac-sweep-21
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/xn13uuik
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▅▂▂▂▁▁▁▁▁
# wandb:    val_acc ▁▆▇▇██████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.85603
# wandb: train_loss 0.47592
# wandb:    val_acc 0.73806
# wandb:   val_loss 0.98005
# wandb:
# wandb: 🚀 View run lilac-sweep-21 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/xn13uuik
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_215442-xn13uuik/logs
# wandb: Agent Starting Run: ewyura6a with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_215739-ewyura6a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fresh-sweep-22
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/ewyura6a
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇▇████
# wandb:   val_loss █▄▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.82572
# wandb: train_loss 0.58647
# wandb:    val_acc 0.68258
# wandb:   val_loss 1.15495
# wandb:
# wandb: 🚀 View run fresh-sweep-22 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/ewyura6a
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_215739-ewyura6a/logs
# wandb: Agent Starting Run: vdi00sav with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_215916-vdi00sav
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ancient-sweep-23
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/vdi00sav
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▇▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.85831
# wandb: train_loss 0.47366
# wandb:    val_acc 0.72571
# wandb:   val_loss 1.01476
# wandb:
# wandb: 🚀 View run ancient-sweep-23 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/vdi00sav
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_215916-vdi00sav/logs
# wandb: Agent Starting Run: nttgvxmj with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_220214-nttgvxmj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run glowing-sweep-24
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/nttgvxmj
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇▇████
# wandb:   val_loss █▄▂▂▂▂▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.83217
# wandb: train_loss 0.56461
# wandb:    val_acc 0.68635
# wandb:   val_loss 1.14827
# wandb:
# wandb: 🚀 View run glowing-sweep-24 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/nttgvxmj
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_220214-nttgvxmj/logs
# wandb: Agent Starting Run: 5her8wgw with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_220350-5her8wgw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run robust-sweep-25
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/5her8wgw
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.86174
# wandb: train_loss 0.46157
# wandb:    val_acc 0.71858
# wandb:   val_loss 1.03973
# wandb:
# wandb: 🚀 View run robust-sweep-25 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/5her8wgw
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_220350-5her8wgw/logs
# wandb: Agent Starting Run: 4ady8vjw with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_220607-4ady8vjw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run jolly-sweep-26
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/4ady8vjw
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▆▇▇▇▇████
# wandb: train_loss █▃▂▂▂▁▁▁▁▁
# wandb:    val_acc ▁▆▇▇▇█████
# wandb:   val_loss █▂▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.87799
# wandb: train_loss 0.40974
# wandb:    val_acc 0.73312
# wandb:   val_loss 1.01277
# wandb:
# wandb: 🚀 View run jolly-sweep-26 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/4ady8vjw
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_220607-4ady8vjw/logs
# wandb: Agent Starting Run: clfg91xq with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 3
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_220834-clfg91xq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gallant-sweep-27
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/clfg91xq
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▃▅▆▇▇████
# wandb: train_loss █▅▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▄▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84772
# wandb: train_loss 0.50725
# wandb:    val_acc 0.71387
# wandb:   val_loss 1.01587
# wandb:
# wandb: 🚀 View run gallant-sweep-27 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/clfg91xq
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_220834-clfg91xq/logs
# wandb: Agent Starting Run: qlwjf2le with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 3
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_221126-qlwjf2le
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dashing-sweep-28
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/qlwjf2le
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▆▆▇▇█████
# wandb:   val_loss █▃▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.86659
# wandb: train_loss 0.45463
# wandb:    val_acc 0.71616
# wandb:   val_loss 1.0603
# wandb:
# wandb: 🚀 View run dashing-sweep-28 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/qlwjf2le
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_221126-qlwjf2le/logs
# wandb: Agent Starting Run: grzqf76q with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250519_221309-grzqf76q
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sage-sweep-29
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/grzqf76q
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.87662
# wandb: train_loss 0.41251
# wandb:    val_acc 0.72197
# wandb:   val_loss 1.03655
# wandb:
# wandb: 🚀 View run sage-sweep-29 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/grzqf76q
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250519_221309-grzqf76q/logs
# wandb: Agent Starting Run: kc1mcw62 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	enc_layers: 1
# ...
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/ladrxesi
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇▇███
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▄▂▂▂▂▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.83859
# wandb: train_loss 0.53016
# wandb:    val_acc 0.71375
# wandb:   val_loss 1.06282
# wandb:
# wandb: 🚀 View run golden-sweep-191 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/ladrxesi
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_044049-ladrxesi/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 8bv48qm2 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 32
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_044351-8bv48qm2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dry-sweep-192
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/8bv48qm2
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▃▅▆▇▇▇███
# wandb: train_loss █▆▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇▇█████
# wandb:   val_loss █▄▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.85127
# wandb: train_loss 0.4951
# wandb:    val_acc 0.71466
# wandb:   val_loss 1.04655
# wandb:
# wandb: 🚀 View run dry-sweep-192 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/8bv48qm2
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_044351-8bv48qm2/logs
# wandb: Agent Starting Run: bqvxv1vd with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: GRU
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 64
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_044609-bqvxv1vd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run floral-sweep-193
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/bqvxv1vd
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▅▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇██████
# wandb:   val_loss █▃▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.87467
# wandb: train_loss 0.41536
# wandb:    val_acc 0.71936
# wandb:   val_loss 1.08672
# wandb:
# wandb: 🚀 View run floral-sweep-193 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/bqvxv1vd
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_044609-bqvxv1vd/logs
# wandb: Agent Starting Run: thg4u1rr with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_044907-thg4u1rr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run denim-sweep-194
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/thg4u1rr
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▂▄▆▆▇▇███
# wandb: train_loss █▇▄▃▂▂▂▁▁▁
# wandb:    val_acc ▁▄▅▆▇▇████
# wandb:   val_loss █▅▃▂▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.79656
# wandb: train_loss 0.66517
# wandb:    val_acc 0.70594
# wandb:   val_loss 1.03174
# wandb:
# wandb: 🚀 View run denim-sweep-194 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/thg4u1rr
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_044907-thg4u1rr/logs
# wandb: Agent Starting Run: r2bzco8x with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 32
# wandb: 	enc_layers: 3
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_045214-r2bzco8x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vital-sweep-195
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/r2bzco8x
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▃▅▆▇▇▇███
# wandb: train_loss █▆▄▃▂▂▁▁▁▁
# wandb:    val_acc ▁▄▆▇▇▇▇███
# wandb:   val_loss █▅▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.85582
# wandb: train_loss 0.48046
# wandb:    val_acc 0.73131
# wandb:   val_loss 1.02091
# wandb:
# wandb: 🚀 View run vital-sweep-195 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/r2bzco8x
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_045214-r2bzco8x/logs
# wandb: Agent Starting Run: 5pie7eb5 with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: False
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_045522-5pie7eb5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run still-sweep-196
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/5pie7eb5
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▂▄▅▆▇▇███
# wandb: train_loss █▇▅▃▂▂▂▁▁▁
# wandb:    val_acc ▁▃▅▆▇▇████
# wandb:   val_loss █▆▄▂▂▂▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.78375
# wandb: train_loss 0.70999
# wandb:    val_acc 0.69761
# wandb:   val_loss 1.04353
# wandb:
# wandb: 🚀 View run still-sweep-196 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/5pie7eb5
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_045522-5pie7eb5/logs
# wandb: Agent Starting Run: inoqfjlx with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 16
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_045740-inoqfjlx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run true-sweep-197
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/inoqfjlx
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▇▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.82229
# wandb: train_loss 0.58
# wandb:    val_acc 0.72256
# wandb:   val_loss 0.96493
# wandb:
# wandb: 🚀 View run true-sweep-197 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/inoqfjlx
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_045740-inoqfjlx/logs
# wandb: Agent Starting Run: pld6zd7e with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	enc_layers: 3
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_050007-pld6zd7e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run generous-sweep-198
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/pld6zd7e
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▄▆▆▇▇████
# wandb: train_loss █▅▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▇▇▇█████
# wandb:   val_loss █▃▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.86151
# wandb: train_loss 0.4621
# wandb:    val_acc 0.71853
# wandb:   val_loss 1.08466
# wandb:
# wandb: 🚀 View run generous-sweep-198 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/pld6zd7e
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_050007-pld6zd7e/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: jjjpu1wh with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 1
# wandb: 	cell_type: GRU
# wandb: 	dec_layers: 2
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 16
# wandb: 	enc_layers: 2
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_050309-jjjpu1wh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run helpful-sweep-199
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/jjjpu1wh
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▅▆▇▇▇████
# wandb: train_loss █▄▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▇▇▇█████
# wandb:   val_loss █▃▂▂▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84082
# wandb: train_loss 0.52261
# wandb:    val_acc 0.73478
# wandb:   val_loss 0.95104
# wandb:
# wandb: 🚀 View run helpful-sweep-199 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/jjjpu1wh
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_050309-jjjpu1wh/logs
# wandb: Agent Starting Run: xu42965t with config:
# wandb: 	batch_size: 128
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dec_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	enc_layers: 1
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	use_attn: True
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_050552-xu42965t
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run logical-sweep-200
# wandb: ⭐️ View project at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: 🧹 View sweep at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/sweeps/lq4q39fn
# wandb: 🚀 View run at https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/xu42965t
# wandb:
# wandb:
# wandb: Run history:
# wandb:      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:  train_acc ▁▃▆▇▇▇████
# wandb: train_loss █▅▃▂▂▂▁▁▁▁
# wandb:    val_acc ▁▅▆▇██████
# wandb:   val_loss █▃▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      epoch 10
# wandb:  train_acc 0.84629
# wandb: train_loss 0.50883
# wandb:    val_acc 0.731
# wandb:   val_loss 0.97244
# wandb:
# wandb: 🚀 View run logical-sweep-200 at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit/runs/xu42965t
# wandb: ⭐️ View project at: https://wandb.ai/da24s006-indian-institue-of-technology-madras-/dakshina-translit
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250520_050552-xu42965t/logs

# %% [markdown]
# # test set predictions

# %%
import torch

# 1. Load the saved state dict
state_dict = torch.load('model_use_attn.pt', map_location='cpu')

# 2. Print every parameter name and its shape
print("Saved parameters and shapes:\n")
for name, tensor in state_dict.items():
    print(f"{name:40s} → {tuple(tensor.shape)}")
# Out:
# Saved parameters and shapes:
#
# enc.emb.weight                           → (29, 64)
# enc.rnn.weight_ih_l0                     → (1024, 64)
# enc.rnn.weight_hh_l0                     → (1024, 256)
# enc.rnn.bias_ih_l0                       → (1024,)
# enc.rnn.bias_hh_l0                       → (1024,)
# dec.emb.weight                           → (66, 64)
# dec.rnn.weight_ih_l0                     → (1024, 320)
# dec.rnn.weight_hh_l0                     → (1024, 256)
# dec.rnn.bias_ih_l0                       → (1024,)
# dec.rnn.bias_hh_l0                       → (1024,)
# dec.rnn.weight_ih_l1                     → (1024, 256)
# dec.rnn.weight_hh_l1                     → (1024, 256)
# dec.rnn.bias_ih_l1                       → (1024,)
# dec.rnn.bias_hh_l1                       → (1024,)
# dec.rnn.weight_ih_l2                     → (1024, 256)
# dec.rnn.weight_hh_l2                     → (1024, 256)
# dec.rnn.bias_ih_l2                       → (1024,)
# dec.rnn.bias_hh_l2                       → (1024,)
# dec.fc.weight                            → (66, 256)
# dec.fc.bias                              → (66,)
# dec.attn.attn.weight                     → (256, 512)
# dec.attn.attn.bias                       → (256,)
# dec.attn.v.weight                        → (1, 256)

# %%
# import torch
# from torch.utils.data import DataLoader

# # Paths and device
# test_path = '/kaggle/input/transliteration-9123/hi.translit.sampled.test.tsv'
# device    = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# pad_idx   = tgt_vocab['<pad>']

# # 1. Prepare test DataLoader
# test_dataset = TransliterationDataset(test_path, src_vocab, tgt_vocab)
# test_loader  = DataLoader(test_dataset, batch_size=128, collate_fn=collate_fn)

# # 2. Re‐create the model with best hyperparameters
# #    Replace these values with your actual best config
# best_emb_dim    = 256
# best_hid_dim    = 256
# best_enc_layers = 1
# best_dec_layers = 1
# best_cell_type  = 'LSTM'
# best_dropout    = 0.3


# enc = Encoder(len(src_vocab), best_emb_dim, best_hid_dim,
#               best_enc_layers, best_cell_type, best_dropout)
# dec = Decoder(len(tgt_vocab), best_emb_dim, best_hid_dim,
#               best_dec_layers, best_cell_type, best_dropout,
#               use_attn=False)
# model = Seq2Seq(enc, dec, pad_idx, device).to(device)

# # 3. Load the saved weights
# model.load_state_dict(torch.load('model_use_attn.pt', map_location=device))
# model.eval()

# # 4. Define the loss criterion
# criterion = torch.nn.CrossEntropyLoss(ignore_index=pad_idx)

# dv = TransliterationDataset('/kaggle/input/transliteration-9123/hi.translit.sampled.dev.tsv', src_vocab, tgt_vocab)
# val_dl = DataLoader(dv, batch_size=128, collate_fn=collate_fn)


# # 5. Run evaluation on the test set
# test_loss, test_acc = eval_epoch(model, test_loader, criterion,
#                                  beam_k=1, pad_idx=pad_idx)

# print(f"Test Loss: {test_loss:.4f}")
# print(f"Test Token‐level Accuracy: {test_acc:.4%}")

# %%
# def sweep_run():
#     wandb.init()
#     cfg = wandb.config
    
#     # data
#     ds = TransliterationDataset('/kaggle/input/transliteration-9123/hi.translit.sampled.train.tsv', src_vocab, tgt_vocab)
#     dv = TransliterationDataset('/kaggle/input/transliteration-9123/hi.translit.sampled.dev.tsv', src_vocab, tgt_vocab)
#     dl = DataLoader(ds, batch_size=cfg.batch_size, collate_fn=collate_fn, shuffle=True)
#     val_dl = DataLoader(dv, batch_size=cfg.batch_size, collate_fn=collate_fn)
    
#     # model
#     enc = Encoder(len(src_vocab), cfg.emb_dim, cfg.hid_dim, cfg.enc_layers, cfg.cell_type, cfg.dropout)
#     dec = Decoder(len(tgt_vocab), cfg.emb_dim, cfg.hid_dim, cfg.dec_layers, cfg.cell_type, cfg.dropout, use_attn=False)
#     model = Seq2Seq(enc,dec,pad_idx,device).to(device)
#     opt   = optim.Adam(model.parameters(), lr=cfg.lr)
#     crit  = nn.CrossEntropyLoss(ignore_index=pad_idx)

#     for epoch in range(1, 11):
#         tr_loss, tr_acc = train_epoch(model, dl, opt, crit, pad_idx)
#         vl_loss, vl_acc = eval_epoch(model, val_dl, crit, cfg.beam_size, pad_idx)
#         wandb.log({
#             'epoch':       epoch,
#             'train_loss':  tr_loss,
#             'train_acc':   tr_acc,
#             'val_loss':    vl_loss,
#             'val_acc':     vl_acc
#         })
            
#     # save best
#     torch.save(model.state_dict(),'model.pt')
#     wandb.save('model.pt')

# if __name__=='__main__':
#     sweep_id = wandb.sweep(sweep_config, project='dakshina-translit')
#     wandb.agent(sweep_id, function=sweep_run)

# %% [markdown]
# # CHECK
